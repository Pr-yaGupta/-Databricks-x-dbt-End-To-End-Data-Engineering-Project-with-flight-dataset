# %%
parameters = [
  {
    "file_name" : "bookings"
  },
  {
    "file_name" : "airports"
  },
  {
    "file_name" : "flights"
  },
  {
    "file_name" : "passengers"
  }
]

# %%
dbutils.jobs.taskValues.set(key = "parameters", value = parameters)
