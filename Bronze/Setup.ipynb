# %%
# %sql
-- Managed volume
CREATE VOLUME databricks_flight_catalog.raw.rawvolume

# %%
dbutils.fs.mkdirs("/Volumes/databricks_flight_catalog/raw/rawvolume/rawdata")
# Out:
# True

# %%
dbutils.fs.mkdirs("/Volumes/databricks_flight_catalog/raw/rawvolume/rawdata/airports")
dbutils.fs.mkdirs("/Volumes/databricks_flight_catalog/raw/rawvolume/rawdata/passengers")
dbutils.fs.mkdirs("/Volumes/databricks_flight_catalog/raw/rawvolume/rawdata/bookings")
dbutils.fs.mkdirs("/Volumes/databricks_flight_catalog/raw/rawvolume/rawdata/flights")
# Out:
# True

# %%
# %sql
CREATE VOLUME databricks_flight_catalog.raw.bronze;
CREATE VOLUME databricks_flight_catalog.raw.silver;
CREATE VOLUME databricks_flight_catalog.raw.gold;

# %%
# %sql
DROP VOLUME databricks_flight_catalog.raw.bronze;
DROP VOLUME databricks_flight_catalog.raw.silver;
DROP VOLUME databricks_flight_catalog.raw.gold;

# %%
# %sql
CREATE SCHEMA databricks_flight_catalog.bronze;
CREATE SCHEMA databricks_flight_catalog.silver;
CREATE SCHEMA databricks_flight_catalog.gold;

# %%
# %sql
CREATE VOLUME databricks_flight_catalog.bronze.bronzevolume;
CREATE VOLUME databricks_flight_catalog.silver.silvervolume;
CREATE VOLUME databricks_flight_catalog.gold.goldvolume;
